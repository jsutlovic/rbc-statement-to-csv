# %%
from typing import NamedTuple
import xml.etree.ElementTree as ET
from itertools import accumulate, starmap
from functools import reduce
import random
from parsel import Selector

# %%
class BBox(NamedTuple):
    left: float
    bottom: float
    right: float
    top: float

    def to_attr(self):
        return ",".join(map(lambda f: "{0:.3f}".format(getattr(self, f)), self._fields))

    def process_tag(tag: Selector) -> BBox:
        # Expect a comma-separated list of 4 coordinates in order: left, top, right, bottom
        # Parse them into a list of strings
        str_coords = tag.attrib.get("bbox", "0,0,0,0").split(",")
        # Use map to convert to a list of floats
        coords = map(float, str_coords)
        # Unpack coords
        return BBox(*coords)

def gen_textline(text: str, left: float, bottom: float, font: str, size: float, **attrs):
    tag_attrs = {"font": font, "size": str(size)}
    tag_attrs.update(attrs)

    top = bottom + size
    start_left = left
    textline_tag = ET.Element("textline")
    for char in text:
        w = random.uniform(2.3, 7.2)
        right = start_left + w
        bbox = BBox(start_left, bottom, right, top)

        if char in [" ", "\n"]:
            text_tag = ET.Element("text")
            start_left = right if char == " " else start_left
        else:
            text_tag = ET.Element("text", **tag_attrs, bbox=bbox.to_attr())
            start_left = right

        text_tag.text = char
        textline_tag.append(text_tag)

    bbox = BBox(left, bottom, start_left, top)
    textline_tag.set("bbox", bbox.to_attr())
    return textline_tag

attribs = {
    "left": 90.0,
    "bottom": 10.0,
    "font": "CSBRTR+MetaBookLF-Roman",
    "size": 9.0,
    "colourspace": "DeviceGray",
    "ncolour": "0",
}
tl = gen_textline("Hello world\n", **attribs)
ET.indent(tl)
ET.dump(tl)
# Out:
# <textline bbox="90.000,10.000,143.713,19.000">
#   <text font="CSBRTR+MetaBookLF-Roman" size="9.0" colourspace="DeviceGray" ncolour="0" bbox="90.000,10.000,96.510,19.000">H</text>
#   <text font="CSBRTR+MetaBookLF-Roman" size="9.0" colourspace="DeviceGray" ncolour="0" bbox="96.510,10.000,102.295,19.000">e</text>
#   <text font="CSBRTR+MetaBookLF-Roman" size="9.0" colourspace="DeviceGray" ncolour="0" bbox="102.295,10.000,104.842,19.000">l</text>
#   <text font="CSBRTR+MetaBookLF-Roman" size="9.0" colourspace="DeviceGray" ncolour="0" bbox="104.842,10.000,111.960,19.000">l</text>
#   <text font="CSBRTR+MetaBookLF-Roman" size="9.0" colourspace="DeviceGray" ncolour="0" bbox="111.960,10.000,115.360,19.000">o</text>
#   <text> </text>
#   <text font="CSBRTR+MetaBookLF-Roman" size="9.0" colourspace="DeviceGray" ncolour="0" bbox="119.426,10.000,123.344,19.000">w</text>
#   <text font="CSBRTR+MetaBookLF-Roman" size="9.0" colourspace="DeviceGray" ncolour="0" bbox="123.344,10.000,127.066,19.000">o</text>
#   <text font="CSBRTR+MetaBookLF-Roman" size="9.0" colourspace="DeviceGray" ncolour="0" bbox="127.066,10.000,134.072,19.000">r</text>
#   <text font="CSBRTR+MetaBookLF-Roman" size="9.0" colourspace="DeviceGray" ncolour="0" bbox="134.072,10.000,139.131,19.000">l</text>
#   <text font="CSBRTR+MetaBookLF-Roman" size="9.0" colourspace="DeviceGray" ncolour="0" bbox="139.131,10.000,143.713,19.000">d</text>
#   <text>
# </text>
# </textline>

# %%
e = ET.Element("test")
e.extend(iter([ET.Element("tt", text=" ")]))
ET.dump(e)
# Out:
# <test><tt text=" " /></test>

# %%
t = 9.0
b = 1.0
bb = BBox(0.0, b, 100.0, t)
def mf(left, bottom, right, top):
    w = random.uniform(2.3, 7.2)
    return BBox(right, bottom, right+w, top)

w_gen = lambda: random.uniform(2.3, 7.2)
list(accumulate(map(lambda c: (w_gen(), c), "Hello"), lambda tot, el: (tot[0] + el[0], el[1])))
# Out:
# [(3.843886154991215, 'H'),
#  (9.281238908400304, 'e'),
#  (13.258205084992266, 'l'),
#  (17.064033711544806, 'l'),
#  (20.835528910542003, 'o')]

# %%
i_char = tuple(map(float, "97.190,272.163,99.575,281.163".split(",")))
print(f"i width: {i_char[2]-i_char[0]:.3f}")
m_char = tuple(map(float, "90.000,272.163,97.191,281.163".split(",")))
print(f"m width: {m_char[2]-m_char[0]:.3f}")
# Out:
# i width: 2.385
# m width: 7.191

# %%
with open("test_may_2023_new.xml") as xml_fp:
    xml_text = xml_fp.read()

s = Selector(text=xml_text, type="xml")
s
# Out:
# <Selector query=None data='<pages>\n  <page id="1" bbox="0.000,0....'>

# %%
mapping_key = NamedTuple("mapping_key", [("char", str), ("font", str), ("w", float)])
keys = map(lambda t: mapping_key(t.xpath("text()").get(), f"{t.attrib.get('font').split('+')[-1]}@{float(t.attrib.get('size'))}", (bbox := BBox.process_tag(t), round(bbox.right-bbox.left, 3))[-1]), s.xpath(".//text[@bbox]"))
reduce(lambda d, mpk: (d | {mpk.char: (dd := d.get(mpk.char, {}), dd | {mpk.font: dd.get(mpk.font, set()) | {mpk.w}})[-1]}), sorted(keys, key=lambda mpk: mpk.char), {})
# Out:
# {'#': {'MetaBookLF-Roman@9.0': {4.959}},
#  '$': {'MetaBoldLF-Roman@8.0': {4.672},
#   'MetaBookLF-Roman@9.0': {5.238},
#   'MetaBoldLF-Roman@9.0': {5.256}},
#  '(': {'Utopia-Regular@8.5': {2.975}, 'MetaBoldLF-Roman@8.0': {2.496}},
#  ')': {'Utopia-Regular@8.5': {2.975}, 'MetaBoldLF-Roman@8.0': {2.48}},
#  '*': {'C39-Medium24ptLJ3A@14.768': {26.0}},
#  '+': {'MetaBookLF-Roman@9.0': {5.085}},
#  ',': {'Utopia-Regular@9.0': {2.385},
#   'MetaBookLF-Roman@9.0': {2.583},
#   'MetaBoldLF-Roman@9.0': {2.556},
#   'Utopia-Regular@6.0': {1.59}},
#  '-': {'Utopia-Regular@8.5': {3.332},
#   'Utopia-Bold@9.0': {3.528},
#   'MetaBookLF-Roman@9.0': {2.727},
#   'Helvetica@2.664': {8.0},
#   'Utopia-Bold@14.0': {5.488},
#   'Utopia-Regular@6.0': {2.352}},
#  '.': {'Utopia-Regular@8.0': {2.12},
#   'Utopia-Regular@8.5': {2.253},
#   'MetaBookLF-Roman@9.0': {2.538},
#   'MetaBoldLF-Roman@9.0': {2.484},
#   'Utopia-Regular@6.0': {1.59}},
#  '/': {'Utopia-Regular@8.5': {3.91}},
#  '0': {'Utopia-Regular@8.0': {4.24},
#   'Utopia-Regular@9.0': {4.77},
#   'OCRB@10.0': {6.0},
#   'OCRB@8.0': {4.8},
#   'MetaBookLF-Roman@10.0': {5.6},
#   'Utopia-Regular@8.5': {4.505},
#   'MetaBookLF-Roman@9.0': {5.04},
#   'Utopia-Bold@9.0': {5.04},
#   'MetaBoldLF-Roman@9.0': {5.04},
#   'C39-Medium24ptLJ3A@14.768': {26.0},
#   'Helvetica@4.448': {8.0},
#   'Utopia-Regular@6.0': {3.18}},
#  '1': {'Utopia-Regular@8.0': {4.24},
#   'OCRB@10.0': {6.0},
#   'OCRB@8.0': {4.8},
#   'MetaBookLF-Roman@10.0': {5.6},
#   'Utopia-Regular@8.5': {4.505},
#   'MetaBookLF-Roman@9.0': {5.04},
#   'MetaBoldLF-Roman@9.0': {5.04},
#   'Utopia-Regular@9.0': {4.77},
#   'C39-Medium24ptLJ3A@14.768': {26.0},
#   'Helvetica@4.448': {8.0},
#   'Utopia-Regular@6.0': {3.18}},
#  '2': {'Utopia-Regular@9.0': {4.77},
#   'OCRB@8.0': {4.8},
#   'MetaBookLF-Roman@10.0': {5.6},
#   'Utopia-Regular@8.5': {4.505},
#   'MetaBookLF-Roman@9.0': {5.04},
#   'MetaBoldLF-Roman@9.0': {5.04},
#   'Utopia-Bold@9.0': {5.04},
#   'C39-Medium24ptLJ3A@14.768': {26.0},
#   'Helvetica@4.448': {8.0},
#   'Utopia-Regular@6.0': {3.18}},
#  '3': {'Utopia-Regular@9.0': {4.77},
#   'OCRB@8.0': {4.8},
#   'Utopia-Regular@8.5': {4.505},
#   'MetaBookLF-Roman@9.0': {5.04},
#   'Utopia-Bold@9.0': {5.04},
#   'MetaBoldLF-Roman@9.0': {5.04},
#   'Helvetica@4.448': {8.0}},
#  '4': {'Utopia-Regular@8.0': {4.24},
#   'OCRB@8.0': {4.8},
#   'Utopia-Regular@8.5': {4.505},
#   'MetaBookLF-Roman@9.0': {5.04},
#   'Utopia-Bold@9.0': {5.04},
#   'MetaBoldLF-Roman@9.0': {5.04},
#   'Helvetica@4.448': {8.0},
#   'Utopia-Regular@6.0': {3.18}},
#  '5': {'Utopia-Regular@8.0': {4.24},
#   'Utopia-Regular@9.0': {4.77},
#   'OCRB@10.0': {6.0},
#   'OCRB@8.0': {4.8},
#   'Utopia-Regular@8.5': {4.505},
#   'MetaBookLF-Roman@9.0': {5.04},
#   'Utopia-Bold@9.0': {5.04},
#   'MetaBoldLF-Roman@9.0': {5.04},
#   'Helvetica@4.448': {8.0},
#   'Utopia-Regular@6.0': {3.18}},
#  '6': {'Utopia-Regular@8.5': {4.505},
#   'MetaBookLF-Roman@9.0': {5.04},
#   'Utopia-Bold@9.0': {5.04},
#   'Utopia-Regular@9.0': {4.77},
#   'Utopia-Regular@6.0': {3.18}},
#  '7': {'Utopia-Regular@8.0': {4.24},
#   'OCRB@8.0': {4.8},
#   'Utopia-Regular@8.5': {4.505},
#   'MetaBookLF-Roman@9.0': {5.04},
#   'Utopia-Regular@9.0': {4.77},
#   'MetaBoldLF-Roman@9.0': {5.04},
#   'Helvetica@4.448': {8.0}},
#  '8': {'OCRB@10.0': {6.0},
#   'MetaBookLF-Roman@10.0': {5.6},
#   'Utopia-Regular@8.5': {4.505},
#   'MetaBookLF-Roman@9.0': {5.04},
#   'Helvetica@4.448': {8.0},
#   'Utopia-Regular@6.0': {3.18}},
#  '9': {'MetaBookLF-Roman@10.0': {5.6},
#   'Utopia-Regular@8.5': {4.505},
#   'MetaBookLF-Roman@9.0': {5.04},
#   'Utopia-Bold@9.0': {5.04},
#   'Utopia-Regular@9.0': {4.77},
#   'MetaBoldLF-Roman@9.0': {5.04},
#   'Helvetica@4.448': {8.0}},
#  ':': {'Utopia-Bold@10.0': {2.8}, 'Utopia-Regular@6.0': {1.59}},
#  '=': {'MetaBoldLF-Roman@9.0': {5.652}},
#  'A': {'Utopia-Regular@8.0': {5.08},
#   'Utopia-Regular@9.0': {5.715},
#   'OCRB@8.0': {4.8},
#   'MetaBookLF-Roman@10.0': {5.68},
#   'Utopia-Regular@8.5': {5.398},
#   'MetaBookLF-Roman@9.0': {5.112},
#   'Helvetica@5.336': {8.0},
#   'Utopia-Regular@6.0': {3.81}},
#  'B': {'Utopia-Bold@8.0': {5.464},
#   'Utopia-Regular@8.0': {5.168},
#   'Utopia-Bold@24.0': {16.392},
#   'OCRB@8.0': {4.8},
#   'MetaBoldLF-Roman@8.0': {4.8},
#   'Utopia-Bold@9.0': {6.147},
#   'MetaBookLF-Roman@9.0': {5.382},
#   'Helvetica@5.336': {8.0},
#   'Utopia-Bold@16.0': {10.928},
#   'MetaBoldLF-Roman@9.0': {5.4},
#   'Utopia-Regular@6.0': {3.876}},
#  'C': {'Utopia-Bold@8.0': {5.512},
#   'Utopia-Bold@24.0': {16.536},
#   'MetaBookLF-Roman@10.0': {5.7},
#   'Utopia-Bold@9.0': {6.201},
#   'MetaBookLF-Roman@9.0': {5.13},
#   'Utopia-Bold@16.0': {11.024},
#   'MetaBoldLF-Roman@9.0': {5.076},
#   'Utopia-Regular@6.0': {4.104}},
#  'D': {'OCRB@8.0': {4.8},
#   'MetaBookLF-Roman@10.0': {6.19},
#   'Utopia-Regular@9.0': {7.011},
#   'Utopia-Bold@14.0': {10.878},
#   'MetaBoldLF-Roman@8.0': {4.944},
#   'MetaBookLF-Roman@9.0': {5.571},
#   'Helvetica@5.776': {8.0}},
#  'E': {'OCRB@8.0': {4.8},
#   'MetaBookLF-Roman@10.0': {5.01},
#   'Utopia-Regular@9.0': {5.454},
#   'MetaBookLF-Roman@9.0': {4.509}},
#  'F': {'Utopia-Regular@9.0': {5.22}, 'MetaBookLF-Roman@9.0': {3.906}},
#  'G': {'MetaBookLF-Roman@10.0': {6.37},
#   'MetaBookLF-Roman@9.0': {5.733},
#   'Utopia-Regular@6.0': {4.404}},
#  'H': {'Utopia-Bold@10.0': {8.07},
#   'Utopia-Regular@9.0': {7.182},
#   'MetaBookLF-Roman@9.0': {5.625},
#   'Helvetica@5.776': {8.0}},
#  'I': {'MetaBookLF-Roman@10.0': {2.68},
#   'Utopia-Regular@9.0': {3.141},
#   'MetaBookLF-Roman@9.0': {2.412},
#   'Helvetica@2.224': {8.0},
#   'Utopia-Regular@6.0': {2.094}},
#  'J': {'MetaBookLF-Roman@10.0': {2.73}, 'Utopia-Regular@9.0': {3.15}},
#  'K': {'Utopia-Regular@9.0': {5.922}, 'MetaBookLF-Roman@9.0': {5.112}},
#  'L': {'Utopia-Regular@8.0': {4.544},
#   'MetaBookLF-Roman@10.0': {4.55},
#   'Utopia-Regular@8.5': {4.828},
#   'Utopia-Bold@9.0': {5.265},
#   'Utopia-Regular@9.0': {5.112},
#   'MetaBookLF-Roman@9.0': {4.095}},
#  'M': {'Utopia-Regular@8.0': {7.552},
#   'Utopia-Regular@9.0': {8.496},
#   'MetaBookLF-Roman@10.0': {7.99},
#   'Utopia-Bold@5.4': {4.957},
#   'MetaBoldLF-Roman@9.0': {7.362},
#   'MetaBookLF-Roman@9.0': {7.191},
#   'Utopia-Regular@3.6': {3.398}},
#  'N': {'Utopia-Regular@8.0': {6.24},
#   'MetaBookLF-Roman@10.0': {6.29},
#   'Utopia-Bold@9.0': {6.651},
#   'Utopia-Regular@9.0': {7.02},
#   'MetaBookLF-Roman@9.0': {5.661},
#   'Utopia-Regular@6.0': {4.68}},
#  'O': {'Utopia-Regular@8.0': {6.096},
#   'MetaBookLF-Roman@10.0': {6.72},
#   'Utopia-Regular@8.5': {6.477},
#   'Utopia-Regular@9.0': {6.858},
#   'MetaBookLF-Roman@9.0': {6.048}},
#  'P': {'Utopia-Regular@8.0': {4.8},
#   'OCRB@8.0': {4.8},
#   'MetaBookLF-Roman@9.0': {4.896},
#   'Helvetica@5.336': {8.0},
#   'Utopia-Regular@6.0': {3.6}},
#  'Q': {'MetaBookLF-Roman@10.0': {6.72}, 'MetaBookLF-Roman@9.0': {6.048}},
#  'R': {'Utopia-Bold@8.0': {5.472},
#   'Utopia-Bold@24.0': {16.416},
#   'OCRB@8.0': {4.8},
#   'MetaBookLF-Roman@10.0': {5.56},
#   'Utopia-Regular@8.5': {5.474},
#   'Utopia-Bold@9.0': {6.156},
#   'Utopia-Regular@9.0': {5.796},
#   'MetaBookLF-Roman@9.0': {5.004},
#   'Helvetica@5.776': {8.0},
#   'Utopia-Bold@16.0': {10.944},
#   'Utopia-Regular@6.0': {3.864}},
#  'S': {'MetaBookLF-Roman@10.0': {5.82},
#   'Utopia-Bold@14.0': {7.854},
#   'Utopia-Bold@9.0': {5.049},
#   'Utopia-Regular@9.0': {4.869},
#   'MetaBookLF-Roman@9.0': {5.238},
#   'Utopia-Regular@6.0': {3.246}},
#  'T': {'Utopia-Regular@8.0': {4.968},
#   'MetaBookLF-Roman@10.0': {4.63},
#   'Utopia-Bold@5.4': {3.37},
#   'MetaBookLF-Roman@9.0': {4.167},
#   'Utopia-Regular@3.6': {2.236},
#   'Utopia-Regular@6.0': {3.726}},
#  'U': {'MetaBookLF-Roman@10.0': {6.24}, 'MetaBookLF-Roman@9.0': {5.616}},
#  'V': {'MetaBookLF-Roman@10.0': {5.68},
#   'Utopia-Regular@9.0': {5.706},
#   'MetaBookLF-Roman@9.0': {5.112}},
#  'W': {'Utopia-Regular@8.0': {7.52}, 'MetaBoldLF-Roman@8.0': {6.656}},
#  'Y': {'Utopia-Bold@24.0': {14.808},
#   'Utopia-Bold@10.0': {6.17},
#   'Utopia-Regular@8.5': {4.998},
#   'MetaBookLF-Roman@9.0': {4.572},
#   'MetaBoldLF-Roman@9.0': {4.806},
#   'Utopia-Bold@16.0': {9.872}},
#  '_': {'OCRB@8.0': {4.8}, 'Helvetica@4.448': {8.0}},
#  'a': {'Utopia-Bold@8.0': {4.352},
#   'Utopia-Regular@8.0': {4.184},
#   'Utopia-Bold@24.0': {13.056},
#   'Utopia-Regular@9.0': {4.707},
#   'Utopia-Bold@10.0': {5.44},
#   'Utopia-Regular@8.5': {4.446},
#   'MetaBoldLF-Roman@8.0': {4.096},
#   'Utopia-Bold@14.0': {7.616},
#   'Utopia-Bold@9.0': {4.896},
#   'MetaBookLF-Roman@9.0': {4.626},
#   'MetaBoldLF-Roman@9.0': {4.608},
#   'Utopia-Bold@16.0': {8.704},
#   'Utopia-Regular@6.0': {3.138}},
#  'b': {'Utopia-Bold@24.0': {14.52},
#   'Utopia-Bold@10.0': {6.05},
#   'Utopia-Regular@8.5': {5.083},
#   'MetaBookLF-Roman@9.0': {5.004},
#   'MetaBoldLF-Roman@9.0': {4.968},
#   'Utopia-Bold@16.0': {9.68},
#   'Utopia-Regular@6.0': {3.588}},
#  'c': {'Utopia-Bold@24.0': {11.856},
#   'Utopia-Bold@10.0': {4.94},
#   'Utopia-Regular@8.5': {4.216},
#   'MetaBoldLF-Roman@8.0': {3.64},
#   'Utopia-Bold@14.0': {6.916},
#   'MetaBookLF-Roman@9.0': {4.077},
#   'MetaBoldLF-Roman@9.0': {4.095},
#   'Utopia-Bold@16.0': {7.904},
#   'Utopia-Regular@6.0': {2.976}},
#  'd': {'Utopia-Bold@8.0': {4.84},
#   'Utopia-Regular@8.5': {5.083},
#   'Utopia-Bold@14.0': {8.47},
#   'Utopia-Bold@9.0': {5.445},
#   'MetaBookLF-Roman@9.0': {4.995},
#   'MetaBoldLF-Roman@8.0': {4.392},
#   'Utopia-Regular@6.0': {3.588}},
#  'e': {'Utopia-Regular@8.0': {4.112},
#   'Utopia-Bold@24.0': {12.456},
#   'Utopia-Bold@10.0': {5.19},
#   'Utopia-Regular@8.5': {4.369},
#   'MetaBoldLF-Roman@8.0': {4.048},
#   'Utopia-Bold@14.0': {7.266},
#   'Utopia-Bold@9.0': {4.671},
#   'MetaBookLF-Roman@9.0': {4.572},
#   'MetaBoldLF-Roman@9.0': {4.554},
#   'Utopia-Bold@16.0': {8.304},
#   'Utopia-Regular@6.0': {3.084}},
#  'f': {'Utopia-Bold@8.0': {2.736},
#   'MetaBoldLF-Roman@9.0': {2.736},
#   'Utopia-Bold@14.0': {4.788},
#   'Utopia-Bold@9.0': {3.078},
#   'MetaBookLF-Roman@9.0': {2.7},
#   'Utopia-Regular@6.0': {1.914}},
#  'g': {'Utopia-Bold@24.0': {12.792},
#   'Utopia-Bold@9.0': {4.797},
#   'MetaBookLF-Roman@9.0': {4.779},
#   'MetaBoldLF-Roman@9.0': {4.977},
#   'Utopia-Bold@16.0': {8.528},
#   'Utopia-Regular@6.0': {3.12}},
#  'h': {'Utopia-Bold@10.0': {6.31},
#   'Utopia-Bold@14.0': {8.834},
#   'MetaBookLF-Roman@9.0': {5.022},
#   'MetaBoldLF-Roman@8.0': {4.52},
#   'Utopia-Regular@6.0': {3.642}},
#  'i': {'Utopia-Regular@8.0': {2.328},
#   'Utopia-Bold@24.0': {7.584},
#   'Utopia-Regular@9.0': {2.619},
#   'Utopia-Regular@8.5': {2.473},
#   'Utopia-Bold@14.0': {4.424},
#   'Utopia-Bold@9.0': {2.844},
#   'MetaBookLF-Roman@9.0': {2.385},
#   'MetaBoldLF-Roman@9.0': {2.466},
#   'MetaBoldLF-Roman@8.0': {2.192},
#   'Utopia-Bold@16.0': {5.056},
#   'Utopia-Regular@6.0': {1.746}},
#  'k': {'Utopia-Bold@8.0': {4.656},
#   'Utopia-Bold@24.0': {13.968},
#   'Utopia-Regular@8.5': {4.454},
#   'Utopia-Bold@9.0': {5.238},
#   'MetaBookLF-Roman@9.0': {4.572},
#   'Utopia-Bold@16.0': {9.312},
#   'Utopia-Regular@6.0': {3.144}},
#  'l': {'Utopia-Bold@8.0': {2.472},
#   'Utopia-Regular@8.0': {2.232},
#   'Utopia-Bold@24.0': {7.416},
#   'Utopia-Regular@9.0': {2.511},
#   'Utopia-Regular@8.5': {2.372},
#   'MetaBoldLF-Roman@8.0': {2.248},
#   'Utopia-Bold@9.0': {2.781},
#   'MetaBookLF-Roman@9.0': {2.376},
#   'MetaBoldLF-Roman@9.0': {2.529},
#   'Utopia-Bold@14.0': {4.326},
#   'Utopia-Bold@16.0': {4.944},
#   'Utopia-Regular@6.0': {1.674}},
#  'm': {'Utopia-Regular@8.0': {7.384},
#   'Utopia-Bold@24.0': {22.752},
#   'Utopia-Regular@9.0': {8.307},
#   'Utopia-Bold@10.0': {9.48},
#   'Utopia-Regular@8.5': {7.846},
#   'Utopia-Bold@14.0': {13.272},
#   'Utopia-Bold@9.0': {8.532},
#   'MetaBookLF-Roman@9.0': {7.164},
#   'Utopia-Bold@16.0': {15.168},
#   'Utopia-Regular@6.0': {5.538}},
#  'n': {'Utopia-Bold@8.0': {5.104},
#   'Utopia-Regular@8.0': {4.952},
#   'Utopia-Bold@24.0': {15.312},
#   'Utopia-Bold@10.0': {6.38},
#   'Utopia-Regular@8.5': {5.262},
#   'MetaBoldLF-Roman@8.0': {4.352},
#   'Utopia-Bold@14.0': {8.932},
#   'Utopia-Bold@9.0': {5.742},
#   'MetaBookLF-Roman@9.0': {4.887},
#   'MetaBoldLF-Roman@9.0': {4.896},
#   'Utopia-Bold@16.0': {10.208},
#   'Utopia-Regular@6.0': {3.714}},
#  'o': {'Utopia-Bold@8.0': {4.68},
#   'Utopia-Regular@8.0': {4.616},
#   'Utopia-Bold@24.0': {14.04},
#   'Utopia-Regular@9.0': {5.193},
#   'Utopia-Bold@10.0': {5.85},
#   'Utopia-Regular@8.5': {4.905},
#   'MetaBoldLF-Roman@9.0': {4.797},
#   'Utopia-Bold@14.0': {8.19},
#   'Utopia-Bold@9.0': {5.265},
#   'MetaBookLF-Roman@9.0': {4.815},
#   'MetaBoldLF-Roman@8.0': {4.264},
#   'Utopia-Bold@16.0': {9.36},
#   'Utopia-Regular@6.0': {3.462}},
#  'p': {'Utopia-Bold@24.0': {14.76},
#   'Utopia-Regular@9.0': {5.472},
#   'Utopia-Regular@8.5': {5.168},
#   'Utopia-Bold@14.0': {8.61},
#   'MetaBookLF-Roman@9.0': {4.986},
#   'MetaBoldLF-Roman@8.0': {4.416},
#   'Utopia-Bold@16.0': {9.84},
#   'Utopia-Regular@6.0': {3.648}},
#  'q': {'MetaBookLF-Roman@9.0': {4.986}, 'Utopia-Regular@6.0': {3.546}},
#  'r': {'Utopia-Regular@8.0': {3.112},
#   'Utopia-Bold@24.0': {10.56},
#   'Utopia-Regular@9.0': {3.501},
#   'Utopia-Bold@10.0': {4.4},
#   'Utopia-Regular@8.5': {3.307},
#   'Utopia-Bold@14.0': {6.16},
#   'Utopia-Bold@9.0': {3.96},
#   'MetaBookLF-Roman@9.0': {3.051},
#   'MetaBoldLF-Roman@9.0': {3.123},
#   'MetaBoldLF-Roman@8.0': {2.776},
#   'Utopia-Bold@16.0': {7.04},
#   'Utopia-Regular@6.0': {2.334}},
#  's': {'Utopia-Bold@24.0': {10.704},
#   'Utopia-Bold@10.0': {4.46},
#   'Utopia-Regular@8.5': {3.706},
#   'Utopia-Bold@14.0': {6.244},
#   'MetaBookLF-Roman@9.0': {4.266},
#   'MetaBoldLF-Roman@9.0': {4.329},
#   'MetaBoldLF-Roman@8.0': {3.848},
#   'Utopia-Bold@16.0': {7.136},
#   'Utopia-Regular@6.0': {2.616}},
#  't': {'Utopia-Regular@8.0': {2.752},
#   'Utopia-Bold@24.0': {8.88},
#   'Utopia-Regular@9.0': {3.096},
#   'Utopia-Bold@10.0': {3.7},
#   'Utopia-Regular@8.5': {2.924},
#   'Utopia-Bold@14.0': {5.18},
#   'Utopia-Bold@9.0': {3.33},
#   'MetaBookLF-Roman@9.0': {2.871},
#   'MetaBoldLF-Roman@8.0': {2.728},
#   'Utopia-Bold@16.0': {5.92},
#   'Utopia-Regular@6.0': {2.064}},
#  'u': {'Utopia-Bold@24.0': {15.096},
#   'Utopia-Bold@10.0': {6.29},
#   'Utopia-Bold@14.0': {8.806},
#   'Utopia-Bold@9.0': {5.661},
#   'MetaBookLF-Roman@9.0': {4.878},
#   'MetaBoldLF-Roman@9.0': {4.824},
#   'Utopia-Bold@16.0': {10.064},
#   'Utopia-Regular@6.0': {3.636}},
#  'v': {'Utopia-Bold@14.0': {7.28},
#   'MetaBookLF-Roman@9.0': {4.122},
#   'Utopia-Regular@6.0': {3.024}},
#  'w': {'Utopia-Bold@10.0': {7.74},
#   'Utopia-Regular@8.5': {6.528},
#   'MetaBookLF-Roman@9.0': {6.237},
#   'MetaBoldLF-Roman@8.0': {5.592},
#   'Utopia-Regular@6.0': {4.608}},
#  'x': {'Utopia-Regular@8.0': {3.888}},
#  'y': {'Utopia-Bold@8.0': {4.192},
#   'Utopia-Regular@9.0': {4.554},
#   'Utopia-Regular@8.5': {4.301},
#   'Utopia-Bold@14.0': {7.336},
#   'Utopia-Bold@9.0': {4.716},
#   'MetaBookLF-Roman@9.0': {4.221},
#   'MetaBoldLF-Roman@9.0': {4.473},
#   'Utopia-Regular@6.0': {3.036}},
#  '®': {'Utopia-Regular@5.1': {4.172}, 'Utopia-Regular@3.6': {2.945}}}

# %%
def reduce_dict(d, kv):
    key = kv[0]
    val = kv[1]
    vals = d.get(key, [])
    vals.append(val)
    d[key] = vals
    return d

reduce(lambda d, kv: (d | {f"{kv[0]}": d.get(kv[0], []) + [kv[1]]}), [('a', 1), ('a', 2), ('d', 5), ('b', 1), ('d', 1)], {})
# Out:
# {'a': [1, 2], 'd': [5, 1], 'b': [1]}
